# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %%
aqi_readings=np.random.randint(1,190, size=1440)
print(aqi_readings)
# Out:
# [118 181 147 ...   9  90  21]

# %%
ad=np.arange(0,np.pi,np.pi/1440)
y=np.sin(ad)
plt.plot(ad,y)

# %%
def avg(ad):
    return np.average(ad)

avg(ad)
# Out:
# 1.5697054960124004
